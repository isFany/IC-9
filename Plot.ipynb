# %% [markdown]
# This file is used to plot the pictures in the report. The csv files are uploaded to Github repository

# %% [markdown]
# ## Mounting your google drive
#
# You can use google drive to store and access files e.g. storing and loading data from numpy or CSV files.
# Use the following command to mount your GDrive and access your files.

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt


import torch
from IPython.core.pylabtools import figsize # import figsize
from matplotlib.pyplot import LinearLocator
import matplotlib as mpl
import matplotlib.colors as colors


import os
import time
import platform
print('python version', platform.python_version())
print('torch version', torch.__version__)
print('numpy version', np.version.version)
# Out:
# python version 3.7.11
# torch version 1.9.0+cu102
# numpy version 1.19.5

# %%
def saveNumpy(path, array):
    np.savetxt(path, array, delimiter=',')

def getNumpy(path):
    array = np.loadtxt(path,delimiter=",")
    return array

# %% [markdown]
# # Burgers equation

# %% [markdown]
# ## data

# %% [markdown]
# ### Variable 2

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0) # Set the figure size
plt.rcParams['savefig.dpi'] = 300 # Set the figure pixel
plt.rcParams['figure.dpi'] = 300

# %%
# 0
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_2.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_2.csv"
S_AE = getNumpy(path_AE)

path_SVD_AE = "./BE_results/results_csv/SVD_AE_2.csv"
S_SVD_AE = getNumpy(path_SVD_AE)

path_CAE = "./BE_results/results_csv/CAE_2.csv"
S_CAE = getNumpy(path_CAE)


path_HAE = "./BE_results/results_csv/HAE_2.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,0],label = "Orginal")
ax1.plot(x,S_SVD[:,0], label = "POD")
ax1.plot(x,S_AE[:,0],label="AE")
ax1.plot(x,S_SVD_AE[:,0],label="SVD_AE")
ax1.plot(x,S_CAE[:,0],label="CAE")
ax1.plot(x,S_HAE[:,0],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=0', fontsize=20)
plt.savefig('./BE_results/BE_data_time0_variable2.jpg',bbox_inches='tight')

# %%
# 70
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_2.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_2.csv"
S_AE = getNumpy(path_AE)


path_SVD_AE = "./BE_results/results_csv/SVD_AE_2.csv"
S_SVD_AE = getNumpy(path_SVD_AE)

path_CAE = "./BE_results/results_csv/CAE_2.csv"
S_CAE = getNumpy(path_CAE)

path_HAE = "./BE_results/results_csv/HAE_2.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,70],label = "Orginal")
ax1.plot(x,S_SVD[:,70], label = "POD")
ax1.plot(x,S_AE[:,70],label="AE")
ax1.plot(x,S_SVD_AE[:,70],label="SVD_AE")
ax1.plot(x,S_CAE[:,70],label="CAE")
ax1.plot(x,S_HAE[:,70],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=70', fontsize=20)
plt.savefig('./BE_results/BE_data_time70_variable2.jpg',bbox_inches='tight')

# %%
# 150
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_2.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_2.csv"
S_AE = getNumpy(path_AE)

path_SVD_AE = "./BE_results/results_csv/SVD_AE_2.csv"
S_SVD_AE = getNumpy(path_SVD_AE)


path_CAE = "./BE_results/results_csv/CAE_2.csv"
S_CAE = getNumpy(path_CAE)

path_HAE = "./BE_results/results_csv/HAE_2.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,150],label = "Orginal")
ax1.plot(x,S_SVD[:,150], label = "POD")
ax1.plot(x,S_AE[:,150],label="AE")
ax1.plot(x,S_SVD_AE[:,150],label="SVD_AE")
ax1.plot(x,S_CAE[:,150],label="CAE")
ax1.plot(x,S_HAE[:,150],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=150', fontsize=20)
plt.savefig('./BE_results/BE_data_time150_variable2.jpg',bbox_inches='tight')

# %% [markdown]
# ### Variable 20

# %%
# 0
import os
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_20.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_20.csv"
S_AE = getNumpy(path_AE)


path_SVD_AE = "./BE_results/results_csv/SVD_AE_20.csv"
S_SVD_AE = getNumpy(path_SVD_AE)


path_CAE = "./BE_results/results_csv/CAE_20.csv"
S_CAE = getNumpy(path_CAE)

path_HAE = "./BE_results/results_csv/HAE_20.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,0],label = "Orginal")
ax1.plot(x,S_SVD[:,0], label = "POD")
ax1.plot(x,S_AE[:,0],label="AE")
ax1.plot(x,S_SVD_AE[:,0],label="SVD_AE")
ax1.plot(x,S_CAE[:,0],label="CAE")
ax1.plot(x,S_HAE[:,0],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=0', fontsize=20)
plt.savefig('./BE_results/BE_data_time0_variable20.jpg',bbox_inches='tight')

# %%
# 70
import os
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_20.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_20.csv"
S_AE = getNumpy(path_AE)


path_CAE = "./BE_results/results_csv/CAE_20.csv"
S_CAE = getNumpy(path_CAE)

path_SVD_AE = "./BE_results/results_csv/SVD_AE_20.csv"
S_SVD_AE = getNumpy(path_SVD_AE)

path_HAE = "./BE_results/results_csv/HAE_20.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,70],label = "Orginal")
ax1.plot(x,S_SVD[:,70], label = "POD")
ax1.plot(x,S_AE[:,70],label="AE")
ax1.plot(x,S_SVD_AE[:,70],label="SVD_AE")
ax1.plot(x,S_CAE[:,70],label="CAE")
ax1.plot(x,S_HAE[:,70],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=70', fontsize=20)
plt.savefig('./BE_results/BE_data_time70_variable20.jpg',bbox_inches='tight')

# %%
# 150
import os
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

pathx = "./BE_results/results_csv/x.csv"
path_orginal = "./BE_results/results_csv/orginal.csv"
x = getNumpy(pathx)
S = getNumpy(path_orginal)

path_SVD = "./BE_results/results_csv/SVD_20.csv"
S_SVD = getNumpy(path_SVD)

path_AE = "./BE_results/results_csv/AE_20.csv"
S_AE = getNumpy(path_AE)


path_SVD_AE = "./BE_results/results_csv/SVD_AE_20.csv"
S_SVD_AE = getNumpy(path_SVD_AE)

path_CAE = "./BE_results/results_csv/CAE_20.csv"
S_CAE = getNumpy(path_CAE)

path_HAE = "./BE_results/results_csv/HAE_20.csv"
S_HAE = getNumpy(path_HAE)

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlim(-100,100)
ax1.set_ylim(0,1)
ax1.plot(x,S[:,150],label = "Orginal")
ax1.plot(x,S_SVD[:,150], label = "POD")
ax1.plot(x,S_AE[:,150],label="AE")
ax1.plot(x,S_SVD_AE[:,150],label="SVD_AE")
ax1.plot(x,S_CAE[:,150],label="CAE")
ax1.plot(x,S_HAE[:,150],label="HAE")
ax1.legend(loc = "best",fontsize=16)
ax1.set_xlabel('$position$', fontsize=20)
ax1.set_ylabel('$value$', fontsize=20)
ax1.set_title('Time=150', fontsize=20)
plt.savefig('./BE_results/BE_data_time150_variable20.jpg',bbox_inches='tight')

# %% [markdown]
# ## Train

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
POD =   [1.033e-3,  3.655e-4, 8.577e-5,  2.971e-5,  5.013e-6,  2.122e-8]
AE=    [6.968e-4,  5.958e-5, 1.831e-5,   1.110e-5,  6.339e-6,  4.779e-6]
CAE =  [5.261e-6,  4.297e-6, 7.554e-6,  4.737e-6,  5.492e-6,  3.785e-6]
SVD_AE = [6.852e-4,  2.995e-4, 2.190e-4,  8.412e-5,  5.037e-5, 4.127e-5]
HAE =   [5.261e-6,  1.812e-6, 2.289e-6,  5.955e-6, 7.079e-5, 2.428e-5]
ax1.set_title('MSE of train data', fontsize=20)
x= [1,2,4,6,10,20]
ax1.semilogy(x,POD, '.-',label="POD")
ax1.semilogy(x,AE, '.-',label="AE")
ax1.semilogy(x,CAE, '.-',label="CAE")
ax1.semilogy(x,SVD_AE, '.-',label="SVD-AE")
ax1.semilogy(x,HAE, '.-',label="HAE")

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./BE_results/BE_MSE_train.jpg',bbox_inches='tight')

# %% [markdown]
# ## Valid

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
POD =   [6.509e-4, 2.460e-4, 7.121e-5,  2.783e-5,  4.594e-6,  1.992e-8]
AE=    [4.010e-4,  3.680e-5, 1.154e-5,  6.730e-6, 3.706e-6, 2.929e-6]
CAE =  [3.257e-6,  3.612e-6, 5.278e-6,  3.574e-6,  5.039e-6, 2.828e-6]
SVD_AE = [4.934e-4,  1.887e-4, 1.405e-4,  6.159e-5,  4.726e-5, 3.503e-5]
HAE =   [3.257e-6, 1.559e-6, 1.591e-6, 5.383e-6, 6.480e-5,2.578e-5]
ax1.set_title('MSE of validation data', fontsize=20)
x= [1,2,4,6,10,20]
ax1.semilogy(x,POD, '.-',label="POD")
ax1.semilogy(x,AE, '.-',label="AE")
ax1.semilogy(x,CAE, '.-',label="CAE")
ax1.semilogy(x,SVD_AE, '.-',label="SVD-AE")
ax1.semilogy(x,HAE, '.-',label="HAE")

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./BE_results/BE_MSE_valid.jpg',bbox_inches='tight')

# %% [markdown]
# ## Test

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
POD =   [1.261e-3, 3.705e-4, 1.217e-4,  4.432e-5,  8.305e-6,  3.715e-8]
AE=    [7.488e-4,  8.054e-5, 2.258e-5,  1.304e-5, 7.352e-6,  6.188e-6]
CAE =  [5.735e-6,  5.379e-6, 8.378e-6,  7.210e-6,  6.699e-6, 6.068e-6]
SVD_AE = [7.890e-4,  3.079e-4, 2.239e-4, 1.072e-4,  7.862e-5,  5.758e-5]
HAE =   [5.735e-6, 2.914e-6,  3.037e-6, 5.970e-6,  6.898e-5, 1.945e-5]
ax1.set_title('MSE of test data', fontsize=20)
x= [1,2,4,6,10,20]
ax1.semilogy(x,POD, '.-',label="POD")
ax1.semilogy(x,AE, '.-',label="AE")
ax1.semilogy(x,CAE, '.-',label="CAE")
ax1.semilogy(x,SVD_AE, '.-',label="SVD-AE")
ax1.semilogy(x,HAE, '.-',label="HAE")

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./BE_results/BE_MSE_test.jpg',bbox_inches='tight')

# %% [markdown]
# # FPC

# %% [markdown]
# ## Train

# %%
plt.rcParams['figure.figsize'] = (8.0, 4.0) # Set the figure size
plt.rcParams['savefig.dpi'] = 300 # Set the figure pixel
plt.rcParams['figure.dpi'] = 300 
os.chdir('/content/gdrive/MyDrive/Cola-Notebooks/FYP/YF')

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
SFC_CAE = [2.571e-3, 1.715e-3,  1.800e-3,  7.751e-4,  5.865e-4,  4.398e-4,  3.380e-4,  3.040e-4, 2.989e-4]
HAE=   [2.571e-3,  1.878e-3, 7.673e-4,  6.950e-4,   4.614e-4,  3.605e-4, 2.709e-4,  2.332e-4,  2.258e-4]
SAE =  [2.571e-3,  1.680e-3,  9.525e-4,  9.130e-4, 4.487e-4,  3.023e-4,  2.080e-4,  1.461e-4,  1.151e-4]
SVD_AE = [1.055e-2, 3.336e-3,  2.651e-3,  1.507e-3, 6.536e-4,  2.455e-4,  7.811e-5,  3.236e-5,   2.463e-5]
POD =   [2.107e-2, 1.154e-2,  2.778e-3, 1.631e-3, 7.155e-4, 2.688e-4,  7.061e-5,  1.209e-5,  1.513e-6]
ax1.set_title('MSE of train data', fontsize=20)
x= [1,2,4,8,16,32,64,128,256]
ax1.semilogy(x,SFC_CAE,'.-',label="SFC-CAE")
# ax1.loglog(basex=2,baseSFC_RES=10)
ax1.semilogy(x,POD,'.-',label="POD")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,HAE,'.-',label="HAE")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,SAE,'.-',label="SAE")
# ax1.loglog(basex=2,baseHAE2_res=10)
ax1.semilogy(x,SVD_AE,'.-',label="SVD-AE")
# ax1.loglog(basex=2,baseSVD_res=10)

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./FPC_results/FPC_MSE_train.jpg',bbox_inches='tight')

# %% [markdown]
# ## Valid

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
SFC_CAE = [3.263e-3, 1.627e-3,  1.679e-3,  7.296e-4,  5.631e-4,  4.301e-4,  3.331e-4,  2.970e-4,  2.910e-4]
HAE=   [3.263e-3,  1.847e-3,  7.232e-4,  6.616e-4,  4.432e-4, 3.528e-4,  2.651e-4,  2.268e-4,  2.203e-4]
SAE =  [3.263e-3,  2.383e-3,  1.036e-3,  9.490e-4, 4.488e-4,  2.984e-4,  2.101e-4,  1.467e-4,  1.145e-4]
SVD_AE = [9.996e-3, 3.293e-3,  2.628e-3,  1.465e-3, 6.951e-4,  3.297e-4,  1.867e-4,  1.103e-4,  1.022e-4]
POD =   [2.082e-2,  1.087e-2,  2.770e-3, 1.568e-3, 6.605e-4, 2.628e-4,  8.063e-5,  1.710e-5,  3.390e-6]
ax1.set_title('MSE of valid data', fontsize=20)
x= [1,2,4,8,16,32,64,128,256]
ax1.semilogy(x,SFC_CAE,'.-',label="SFC-CAE")
# ax1.loglog(basex=2,baseSFC_RES=10)
ax1.semilogy(x,POD,'.-',label="POD")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,HAE,'.-',label="HAE")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,SAE,'.-',label="SAE")
# ax1.loglog(basex=2,baseHAE2_res=10)
ax1.semilogy(x,SVD_AE,'.-',label="SVD-AE")
# ax1.loglog(basex=2,baseSVD_res=10)

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./FPC_results/FPC_MSE_valid.jpg',bbox_inches='tight')

# %% [markdown]
# ## Test

# %%
fig = plt.figure(figsize=(10, 7))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('$number$ $of$ $latent$ $variables$', fontsize=20)
ax1.set_ylabel('$MSE$', fontsize=20)
SFC_CAE = [2.767e-3, 1.519e-3,  1.606e-3,  7.196e-4,  5.540e-4, 4.220e-4,  3.248e-4,  2.926e-4, 2.878e-4]
HAE=   [2.767e-3, 1.768e-3,  7.137e-4,  6.488e-4,  4.356e-4, 3.444e-4,  2.596e-4,  2.218e-4,  2.135e-4]
SAE =  [2.767e-3, 2.043e-3,  9.900e-4,  8.842e-4,  4.299e-4, 2.899e-4,  2.017e-4,  1.410e-4,  1.108e-4]
SVD_AE = [1.170e-2, 3.089e-3,  2.501e-3,  1.421e-3,  6.727e-4, 3.184e-4,  1.611e-4,  1.066e-4,  1.001e-4]
POD =   [2.130e-2, 1.239e-2, 2.590e-3,   1.423e-3, 6.523e-4, 2.591e-4,  7.631e-5,  1.641e-5,  3.227e-6]
ax1.set_title('MSE of test data', fontsize=20)
x= [1,2,4,8,16,32,64,128,256]
ax1.semilogy(x,SFC_CAE,'.-',label="SFC-CAE")
# ax1.loglog(basex=2,baseSFC_RES=10)
ax1.semilogy(x,POD,'.-',label="POD")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,HAE,'.-',label="HAE")
# ax1.loglog(basex=2,basePOD_res=10)
ax1.semilogy(x,SAE,'.-',label="SAE")
# ax1.loglog(basex=2,baseHAE2_res=10)
ax1.semilogy(x,SVD_AE,'.-',label="SVD-AE")
# ax1.loglog(basex=2,baseSVD_res=10)

ax1.legend(loc = "best",fontsize=16)
plt.savefig('./FPC_results/FPC_MSE_test.jpg',bbox_inches='tight')
